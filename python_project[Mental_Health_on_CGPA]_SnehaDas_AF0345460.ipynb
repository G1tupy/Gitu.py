# %% [markdown]
# <a href="https://colab.research.google.com/github/G1tupy/Gitu.py/blob/main/python_project%5BMental_Health_on_CGPA%5D_SnehaDas_AF0345460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   NAME : Sneha Das
# *   ID: AF345460
# *   BATCH: ANPC6667
# *  DATE:  03/02/2024

# %% [markdown]
# ***A STATISTICAL RESEARCH ON THE EFFECTS OF MENTAL HEALTH ON STUDENTS’ CGPA***

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os # This module provides a way to interact with the operating system

# %% [markdown]
# # ***Reading the Dataset***

# %%
# Load the dataset from CSV file
df = pd.read_csv('/Student Mental health (1).csv')

# %%
#Displaing the first five rows of the dataset
df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
#Displaing the last five rows of the dataset
df.tail()
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# ...

# %%
#Shape of the Data set
df.shape     # that means index range is 101 and column range is 11
# Out:
# (101, 11)

# %%
# Summary statistics of numerical columns
print("/content/Student Mental health (1).csv")
print(df.describe())
# Out:
# /content/Student Mental health (1).csv
#              Age
# count  100.00000
# mean    20.53000
# std      2.49628
# min     18.00000
# 25%     18.00000
# 50%     19.00000
# 75%     23.00000
# max     24.00000

# %%
#Types of Data
df.dtypes
# Out:
# Timestamp                                        object
# Choose your gender                               object
# Age                                             float64
# What is your course?                             object
# Your current year of Study                       object
# What is your CGPA?                               object
# Marital status                                   object
# Do you have Depression?                          object
# Do you have Anxiety?                             object
# Do you have Panic attack?                        object
# Did you seek any specialist for a treatment?     object
# dtype: object

# %%
#Unique values from the Dataset
df.nunique() #This method in Pandas is used to count the number of unique values in each column of a DataFrame
# Out:
# Timestamp                                       92
# Choose your gender                               2
# Age                                              7
# What is your course?                            49
# Your current year of Study                       7
# What is your CGPA?                               6
# Marital status                                   2
# Do you have Depression?                          2
# Do you have Anxiety?                             2
# Do you have Panic attack?                        2
# Did you seek any specialist for a treatment?     2
# dtype: int64

# %%
#Checking if there is any null or missing values in the Data set

df.isnull()   # this function is used to check for missing or null values in a DataFrame
# Out:
#      Timestamp  Choose your gender    Age  What is your course?  \
# 0        False               False  False                 False
# 1        False               False  False                 False
# 2        False               False  False                 False
# 3        False               False  False                 False
# 4        False               False  False                 False
# ..         ...                 ...    ...                   ...
# 96       False               False  False                 False
# 97       False               False  False                 False
# 98       False               False  False                 False
# 99       False               False  False                 False
# 100      False               False  False                 False
#
#      Your current year of Study  What is your CGPA?  Marital status  \
# 0                         False               False           False
# ...

# %%
#Checking howmany null or missing values in the Data set
df.isnull().sum() #we can see there is one missing value
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
# Remove missing values from the Dataset
df = df.dropna(how='any',axis=0) #dropna() method is used to remove missing values from a DataFrame

# %%
#Checking after passing dropna() function
df.isnull().sum() #we can see there is no missing value
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             0
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
df["Your current year of Study"].unique() # Showing year of study
# Out:
# array(['year 1', 'year 2', 'Year 1', 'year 3', 'year 4', 'Year 2',
#        'Year 3'], dtype=object)

# %%
df["What is your CGPA?"].unique()
# Out:
# array(['3.00 - 3.49', '3.50 - 4.00', '3.50 - 4.00 ', '2.50 - 2.99',
#        '2.00 - 2.49', '0 - 1.99'], dtype=object)

# %%
df["What is your CGPA?"] = df["What is your CGPA?"].str.strip() #This method in Python is used to remove leading and trailing whitespace

# %%
# Convert the values in the 'Your current year of Study' column to lowercase
df['Your current year of Study'] = df['Your current year of Study'].str.lower()

# Display unique values in the modified 'Your current year of Study' column
unique_years = df["Your current year of Study"].unique()

# Print the unique values
print(unique_years)
# Out:
# ['year 1' 'year 2' 'year 3' 'year 4']

# %% [markdown]
# # ***Data Visualization***

# %%
# Distribution of age
plt.figure(figsize=(8, 6)) # Set the size of the plot
sns.histplot(df['Age'], bins=20, kde=True)
# Set the title and axis labels
plt.title('Distribution of Age') #naming the title
plt.xlabel('Age')
plt.ylabel('Count')
plt.show() # Display the plot

# %%
#rename the column
df.rename(columns = {'Choose your gender': 'gender'}, inplace = True)

# %%
# Set the size of the plot
plt.figure(figsize=(12,6))
plt.title("gender distribution")# Set the title of the plot
g = plt.pie(df.gender.value_counts(), explode=(0.025,0.025), labels=df.gender.value_counts().index, colors=['green','red'],autopct='%1.1f%%', startangle=180);
plt.legend()# Add a legend to the pie chart
plt.show()# Display the plot

# %%
# Set the size of the plot
plt.figure(figsize=(12,6))
plt.title("gpa distribution")# Set the title of the plot
g = plt.pie(df['What is your CGPA?'].value_counts(), labels=df['What is your CGPA?'].value_counts().index, colors=['skyblue','navajowhite', 'red','green','yellow'],autopct='%1.1f%%', startangle=180);
plt.legend()# Add a legend to the pie chart
plt.show()# Display the plot

# %%
# Set the size of the plot
plt.figure(figsize=(12,6))
plt.title("depression distribution")# Set the title of the plot
g = plt.pie(df['Do you have Depression?'].value_counts(), labels=df['Do you have Depression?'].value_counts().index, colors=['skyblue','purple'],autopct='%1.1f%%', startangle=180);
plt.legend()# Add a legend to the pie chart
plt.show()# Display the plot

# %%
# Set the size of the plot
plt.figure(figsize=(12,6))
plt.title("Anxiety distribution")# Set the title of the plot
g = plt.pie(df['Do you have Anxiety?'].value_counts(), labels=df['Do you have Anxiety?'].value_counts().index, colors=['orange','navajowhite'],autopct='%1.1f%%', startangle=180);
plt.legend()# Add a legend to the pie chart
plt.show()# Display the plot

# %%
# Set the size of the plot
plt.figure(figsize=(10, 10))

# Create a count plot using Seaborn with 'gender' as hue
sns.countplot(x='Your current year of Study', hue='gender', data=df)

# Set the title of the plot
plt.title("Students studying in a particular year")

# Display the plot
plt.show()

# %%
df.columns.tolist()#function is used to retrieve the column names of a DataFrame
# Out:
# ['Timestamp',
#  'gender',
#  'Age',
#  'What is your course?',
#  'Your current year of Study',
#  'What is your CGPA?',
#  'Marital status',
#  'Do you have Depression?',
#  'Do you have Anxiety?',
#  'Do you have Panic attack?',
#  'Did you seek any specialist for a treatment?']

# %%
#Renaming the column names
df.rename(columns = {'Choose your gender': 'gender','What is your course?': "Course",
 'Your current year of Study': "Year",
 'What is your CGPA?': "CGPA",
 'Do you have Depression?': "Depression",
 'Do you have Anxiety?': "Anxiety",
 'Do you have Panic attack?': "Panic Attack",
 'Did you seek any specialist for a treatment?':"Seeked Treatment"}, inplace = True)

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df['Anxiety'],hue=df['Depression'])
plt.title("Anxiety and Depression");
plt.show()

# %%
# Set the size of the plot
plt.figure(figsize=(10, 10))

# Set the Seaborn theme to "darkgrid"
sns.set_theme(style="darkgrid")

# Create a count plot using Seaborn
# y="Depression": Using the 'Depression' column for the y-axis
# hue="gender": Separating the bars by the 'gender' column
# data=df: Using the DataFrame 'df' as the data source
ax = sns.countplot(x="Depression", hue="gender", data=df)

# Set the title of the plot
plt.title("Depression by Gender")

# Display the plot
plt.show()

# %%
# Set the size of the plot
plt.figure(figsize=(10,10))
# Set the Seaborn theme to "darkgrid"
sns.set_theme(style="darkgrid")
# Create a count plot using Seaborn
# y="Depression": Using the 'Depression' column for the y-axis
# hue="gender": Separating the bars by the 'gender' column
# data=df: Using the DataFrame 'df' as the data source
ax = sns.countplot(x="Depression", hue="Year", data=df)
# Set the title of the plot
plt.title("Depression by study year")
# Display the plot
plt.show()

# %%
# Set the size of the plot
plt.figure(figsize=(10, 10))

# Set the Seaborn theme to "darkgrid"
sns.set_theme(style="darkgrid")

# Create a count plot using Seaborn
# x="Panic Attack": Using the 'Panic Attack' column for the x-axis
# hue="CGPA": Separating the bars by the 'CGPA' column
# data=df: Using the DataFrame 'df' as the data source
ax = sns.countplot(x="Panic Attack", hue="CGPA", data=df)

# Set the title of the plot
plt.title("Panic Attack by CGPA")

# Display the plot
plt.show()

# %%
# Set the size of the plot
plt.figure(figsize=(10, 10))

# Set the Seaborn theme to "darkgrid"
sns.set_theme(style="darkgrid")

# Create a count plot using Seaborn
# x="Depression": Using the 'Depression' column for the x-axis
# hue="CGPA": Separating the bars by the 'CGPA' column
# data=df: Using the DataFrame 'df' as the data source
ax = sns.countplot(x="Depression", hue="CGPA", data=df)

# Set the title of the plot
plt.title("Depression by CGPA")

# Display the plot
plt.show()

# %%
# Set the size of the plot
plt.figure(figsize=(10, 10))

# Set the Seaborn theme to "darkgrid"
sns.set_theme(style="darkgrid")

# Create a count plot using Seaborn
# x="Anxiety": Using the 'Anxiety' column for the x-axis
# hue="CGPA": Separating the bars by the 'CGPA' column
# data=df: Using the DataFrame 'df' as the data source
ax = sns.countplot(x="Anxiety", hue="CGPA", data=df)

# Set the title of the plot
plt.title("Anxiety by CGPA")

# Display the plot
plt.show()

# %%
# Set the size of the plot
plt.figure(figsize=(10, 10))

# Set the Seaborn theme to "darkgrid"
sns.set_theme(style="darkgrid")

# Create a count plot using Seaborn
# x="Depression": Using the 'Depression' column for the x-axis
# hue="CGPA": Separating the bars by the 'CGPA' column
# data=df: Using the DataFrame 'df' as the data source
ax = sns.countplot(x="CGPA", hue="Depression", data=df)

# Set the title of the plot
plt.title("Depression effects on CGPA")

# Display the plot
plt.show()

# %%
# Set the size of the plot
plt.figure(figsize=(10, 10))

# Set the Seaborn theme to "darkgrid"
sns.set_theme(style="darkgrid")

# Create a count plot using Seaborn
# x="Anxiety": Using the 'Anxiety' column for the x-axis
# hue="CGPA": Separating the bars by the 'CGPA' column
# data=df: Using the DataFrame 'df' as the data source
ax = sns.countplot(x="CGPA",hue="Anxiety",  data=df)

# Set the title of the plot
plt.title("Anxiety on CGPA")

# Display the plot
plt.show()
